# %% [markdown]
# <a href="https://colab.research.google.com/github/Maria-lin/F1-Analytics/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
SELECT
    CONCAT(YEAR(dat_trt), LPAD(MONTH(dat_trt), 2, '0')) AS annee_mois,
    'non-rejete' AS sens,
    'PARC' AS rejet,
    'automates marche' AS canal,
    'EUR' AS devise,
    COUNT(DISTINCT nmedd8) AS nb_ope,
    0 AS montant,
    'inter_intrra' AS inter_intrra,
    NULL AS nature_compte,
    'PSSTFRPP' AS bic
FROM trepor_ano.t_dlk_mon_rea_gabemp
WHERE YEAR(dat_trt) IN (2024, 2025, 2026)
GROUP BY
    YEAR(dat_trt),
    MONTH(dat_trt)
ORDER BY annee_mois;

# %%
Parfait, on va structurer ça proprement 💪
Je te fais :

1. ✅ **Ce que tu écris sur le post-it (version courte et claire)**
2. 🎤 **Comment tu le présentes à l’oral (version fluide et pro)**

---

# 🟨 1️⃣ Ce que tu écris sur le post-it (version synthétique)

### 🔹 Automates – Point équipe Olivier Martial

* Présentation du besoin TDB QlikSense (3 TDB : Opérations / Incidents / Parc)
* Alignement : LSB dans TDB Opérations, captures carte dans TDB Incidents
* Identification tables incidents dans le Datalake (doc peu claire, à clarifier)
* Atelier type GAB : recherche info dépôt (non trouvée → à voir si commandable)
* Mise en prod envisagée en juin (info à remonter CODIR)

### 🔹 VOP

* Extraction volumes NOAP motif F006 (absence détermination BIC)
* Écart constaté avec chiffres Splunk
* Revalidation requête → chiffres confirmés

### 🔹 Fichier EPI

* Plus d’accès à la catégorie “hébergement fichier”
* Blocage pour traitement des fichiers

---

# 🎤 2️⃣ Comment tu le présentes à l’oral

Là il faut que tu sois structuré, calme, factuel.

---

## 🟣 1. Automates / QlikSense

Tu peux dire :

> Jeudi j’ai eu un point avec l’équipe d’Olivier Martial concernant les TDB QlikSense sur les automates.
> Ils souhaitent trois tableaux de bord distincts :

* un TDB Opérations (retraits, dépôts, LSB),
* un TDB Incidents (captures de carte…),
* un TDB Parc.

> On a clarifié un point important :
> Les captures de carte seront sorties du TDB Opérations pour aller uniquement dans le TDB Incidents.
> En revanche, les LSB restent bien dans le TDB Opérations.

> Ils envisagent une mise en production en juin, ce qui permettrait de remonter l’information au CODIR.

Ensuite tu enchaînes sur ton travail :

> De mon côté, j’ai identifié les tables incidents dans le Datalake.
> La documentation est assez peu structurée, et il faut qu’on clarifie si les données correspondent bien à des incidents opérationnels ou plutôt à des anomalies techniques GAB (type numéro incorrect, message incorrect).

> On devra aussi vérifier si ces incidents peuvent être regroupés avec les captures de carte dans le TDB Incidents.

Puis l’atelier :

> J’ai ensuite fait un atelier avec Olivier sur la typologie des GAB, notamment pour identifier si un automate fait dépôt, LSB ou uniquement retrait.
> On n’a pas trouvé de colonne indiquant clairement cette information.
> Il faut voir si cette donnée peut être commandée ou ajoutée.

---

## 🟣 2. VOP

Tu peux dire :

> Sur la VOP, j’ai traité une demande spécifique sur les volumes NOAP avec le motif F006, liée à l’absence de détermination des BIC.

> Après extraction, ils ont constaté un écart avec leurs chiffres Splunk.
> Ils m’ont demandé une revérification de ma requête.

> J’ai refait les contrôles : les chiffres sont corrects côté requête.
> Donc l’écart ne vient pas de notre extraction.

Tu restes neutre. Pas défensif. Factuel.

---

## 🟣 3. Fichier EPI

Simple et efficace :

> Concernant les fichiers EPI, je n’ai plus accès à la catégorie “hébergement de fichiers”, ce qui bloque actuellement le traitement.

---

# 🎯 Comment tu dois le présenter (important)

* Parle lentement
* Structure par sujet
* Pas trop de détails techniques
* Sois factuel, pas hésitant
* Termine par les blocages

Ordre idéal :

1. Automates (gros sujet structurant)
2. VOP
3. Blocage EPI

---

Si tu veux, je peux aussi te faire une **version encore plus synthétique en mode 2 minutes chrono** pour que tu sois ultra percutant.

# %% [markdown]
# Parfait, on va structurer ça proprement 💪
# Je te fais :
#
# 1. ✅ **Ce que tu écris sur le post-it (version courte et claire)**
# 2. 🎤 **Comment tu le présentes à l’oral (version fluide et pro)**
#
# ---
#
# # 🟨 1️⃣ Ce que tu écris sur le post-it (version synthétique)
#
# ### 🔹 Automates – Point équipe
#
# * Présentation du besoin TDB QlikSense (3 TDB : Opérations / Incidents / Parc)
# * Alignement : LSB dans TDB Opérations, captures carte dans TDB Incidents
# * Identification tables incidents dans le Datalake (doc peu claire, à clarifier)
# * Atelier type GAB : recherche info dépôt (non trouvée → à voir si commandable)
# * Mise en prod envisagée en juin (info à remonter CODIR)
#
# ### 🔹 VOP
#
# * Extraction volumes NOAP motif F006 (absence détermination BIC)
# * Écart constaté avec chiffres Splunk
# * Revalidation requête → chiffres confirmés
#
# ### 🔹 Fichier EPI
#
# * Plus d’accès à la catégorie “hébergement fichier”
# * Blocage pour traitement des fichiers
#
# ---
#
# # 🎤 2️⃣ Comment tu le présentes à l’oral
#
# Là il faut que tu sois structuré, calme, factuel.
#
# ---
#
# ## 🟣 1. Automates / QlikSense
#
# Tu peux dire :
#
# > Jeudi j’ai eu un point avec l’équipe d’Olivier Martial concernant les TDB QlikSense sur les automates.
# > Ils souhaitent trois tableaux de bord distincts :
#
# * un TDB Opérations (retraits, dépôts, LSB),
# * un TDB Incidents (captures de carte…),
# * un TDB Parc.
#
# > On a clarifié un point important :
# > Les captures de carte seront sorties du TDB Opérations pour aller uniquement dans le TDB Incidents.
# > En revanche, les LSB restent bien dans le TDB Opérations.
#
# > Ils envisagent une mise en production en juin, ce qui permettrait de remonter l’information au CODIR.
#
# Ensuite tu enchaînes sur ton travail :
#
# > De mon côté, j’ai identifié les tables incidents dans le Datalake.
# > La documentation est assez peu structurée, et il faut qu’on clarifie si les données correspondent bien à des incidents opérationnels ou plutôt à des anomalies techniques GAB (type numéro incorrect, message incorrect).
#
# > On devra aussi vérifier si ces incidents peuvent être regroupés avec les captures de carte dans le TDB Incidents.
#
# Puis l’atelier :
#
# > J’ai ensuite fait un atelier avec Olivier sur la typologie des GAB, notamment pour identifier si un automate fait dépôt, LSB ou uniquement retrait.
# > On n’a pas trouvé de colonne indiquant clairement cette information.
# > Il faut voir si cette donnée peut être commandée ou ajoutée.
#
# ---
#
# ## 🟣 2. VOP
#
# Tu peux dire :
#
# > Sur la VOP, j’ai traité une demande spécifique sur les volumes NOAP avec le motif F006, liée à l’absence de détermination des BIC.
#
# > Après extraction, ils ont constaté un écart avec leurs chiffres Splunk.
# > Ils m’ont demandé une revérification de ma requête.
#
# > J’ai refait les contrôles : les chiffres sont corrects côté requête.
# > Donc l’écart ne vient pas de notre extraction.
#
# Tu restes neutre. Pas défensif. Factuel.
#
# ---
#
# ## 🟣 3. Fichier EPI
#
# Simple et efficace :
#
# > Concernant les fichiers EPI, je n’ai plus accès à la catégorie “hébergement de fichiers”, ce qui bloque actuellement le traitement.
#
# ---
#
# # 🎯 Comment tu dois le présenter (important)
#
# * Parle lentement
# * Structure par sujet
# * Pas trop de détails techniques
# * Sois factuel, pas hésitant
# * Termine par les blocages
#
# Ordre idéal :
#
# 1. Automates (gros sujet structurant)
# 2. VOP
# 3. Blocage EPI
#
# ---
#
# Si tu veux, je peux aussi te faire une **version encore plus synthétique en mode 2 minutes chrono** pour que tu sois ultra percutant.
# Projet Détection Anomalies GAB
#
# Démarrage du modèle de prédiction d’anomalies
#
# Travail sur l’historisation (ajout dimension temps : évolution volumes / anomalies / montants moyens)
#
# Objectif : identifier si anomalies structurelles
#
# Début cartographie des anomalies par code postal
#
# 🎤 Comment tu le présentes à l’oral
# 🟣 Projet Détection d’Anomalies GAB
#
# Tu peux dire :
#
# J’ai également commencé à travailler sur le projet de détection d’anomalies GAB.
# Je suis en train de construire un modèle de prédiction d’anomalies.
#
# Ensuite tu expliques “historiser” simplement :
#
# La première étape consiste à historiser les données, c’est-à-dire ajouter la dimension temps.
# L’objectif est d’analyser :
#
# l’évolution mensuelle des volumes,
#
# l’évolution du nombre d’anomalies,
#
# l’évolution des montants moyens.
#
# Puis tu expliques le sens :
#
# L’idée est de vérifier si les anomalies sont ponctuelles ou si elles sont structurelles dans le temps.
#
# Ensuite la cartographie :
#
# En parallèle, je commence à travailler sur une cartographie des anomalies par code postal afin d’identifier d’éventuelles concentrations géographiques.
